# %% [markdown]
# <a href="https://colab.research.google.com/github/Gracey-hub/Practice-work-in-Data-Science/blob/master/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The following command uses pip to install DGL
# By adding '!' infront of the command pip, you can install any packages from pip.

# %%
# !pip install dgl
# !pip install networkx

# %% [markdown]
# ## Then we can import DGL as normal.

# %%
import numpy as np
import torch
import dgl # Import DGL
import networkx as nx

# %%
nx_G = nx.petersen_graph() # use nx to make a graph
nx.draw(nx_G)
dgl_G = dgl.DGLGraph(nx_G) # convert nx graph to DGL graph
print(dgl_G)
# Out:
# DGLGraph(num_nodes=10, num_edges=30,
#          ndata_schemes={}
#          edata_schemes={})
